# %% [markdown]
# # Golden IPYNB 제목 Alpha
#
# 첫 문단입니다. 한글 English Alpha와 특수문자 & < > " ' 를 포함합니다.
#
# - 목록 항목 하나
# - 목록 항목 English
#
# | 구분 | 값 | 비고 |
# | --- | --- | --- |
# | 표 제목 | 표 값 한글 | English Cell |

# %%
message = '코드 셀 Alpha & Beta'
print(message)
# Out:
# 출력 텍스트 Output Alpha
