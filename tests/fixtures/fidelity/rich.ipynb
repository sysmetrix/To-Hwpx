# %% [markdown]
# # IPYNB 재현도 검증
#
# 노트북 첫 마크다운 셀입니다.

# %% [markdown]
# ## 마크다운 서식
#
# **굵게**와 *기울임*, `인라인 코드`가 있습니다.
#
# - 목록 하나
# - 목록 둘
#
# | A | B |
# | --- | --- |
# | 1 | 2 |

# %% [markdown]
# 마크다운 셀 이미지: 그림

# %%
def greet(name):
    return f"안녕하세요, {name}"

print(greet("세계"))
# Out:
# 실행 결과 텍스트 출력입니다
# 둘째 줄 출력

# %%
import numpy as np
result = 6 * 7
result
# Out:
# 42
